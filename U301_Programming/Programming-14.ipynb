# %% [markdown]
# # Programming 1-4
#
# Learning Goals:
#
# - Bubble sort algorithem
# - Linear Search algorithm

# %% [markdown]
# # Algorithms for Simple Sorting

# %% [markdown]
# :::{iframe} https://www.youtube.com/embed/kgBjXUE_Nwc
# :width:80%
#
# Sorting algorithms
# :::

# %% [markdown]
# # Bubble Sort

# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/c/c8/Bubble-sort-example-300px.gif)

# %% [markdown]
# ## Bubble Sort Pseudocode Using For-For Loop
#
# ```{code}
# :linenos:
# PROCEDURE bubble_sort(items)
#
#     // Initialise the variables
#     num_items = LEN(items)
#
#     // Pass through the array of items n-1 times
#     FOR pass_num = 1 TO num_items - 1
#         // Perform a pass
#     	FOR index = 0 TO num_items - 2
#        	    // Compare items to check if they are out of order
#             IF (items[index] > items[index + 1]) THEN
#             	// Swap the items
#             	temp = items[index]
#             	items[index] = items[index + 1]
#             	items[index + 1] = temp
#             ENDIF
#       	NEXT index
#     NEXT pass_num
# ENDPROCEDURE
# ```

# %% [markdown]
# ### 🔑💡 Key ideas for Sorting

# %% [markdown]
# :::{dropdown} What is the data structure used here?
#
# Array (but we use `list` in Python because it's more flexible)
# :::

# %% [markdown]
# :::{dropdown} How to swap values of var1 and var2?
#
# You need a temporary variable `temp`. Then:
#
# 1. assign var1 to temp
# 2. assign var2 to var1
# 3. assign temp to var2
#
# ```
# temp <- var1
# var1 <- var2
# var2 <- temp
# ```
# :::

# %%
# Python swap values example 1
var1 = 5000
var2 = 3000
temp = var1
var1 = var2
var2 = temp

# id() shows the abstract memory address of the object
print(f"var1 is {var1}, at {id(var1)}")
print(f"var2 is {var2}, at {id(var2)}")
print(f"temp is {temp}, at {id(temp)}")
# Out:
# var1 is 3000, at 4563888880
# var2 is 5000, at 4563879376
# temp is 5000, at 4563879376

# %%
# Python swap values example 2
var1 = 5000
var2 = 3000
var1, var2 = var2, var1

# id() shows the abstract memory address of the object
print(f"var1 is {var1}, at {id(var1)}")
print(f"var2 is {var2}, at {id(var2)}")
# Out:
# var1 is 3000, at 2161841905552
# var2 is 5000, at 2161841905616

# %% [markdown]
# :::{dropdown} Give an array of 10 items, what is the index number of the last item?
#
# n-1 so 9 because it starts at 0.
# :::

# %% [markdown]
# :::{dropdown} How do you find the length of an list in Python?
#
# use len()
# :::

# %% [markdown]
# :::{dropdown} How many for loops in the pseudocode?
#
# two. one is inside the other. The inner loop is called a **nested for loop**.
# :::

# %%
# Nested for loop is useful

for i in range(1, 13):
    for j in range(1, 13):
        print(f"{i} × {j} = {i*j}", end="\t")
        if j % 4 == 0:
            print()
    print()
# Out:
# 1 × 1 = 1	1 × 2 = 2	1 × 3 = 3	1 × 4 = 4
# 1 × 5 = 5	1 × 6 = 6	1 × 7 = 7	1 × 8 = 8
# 1 × 9 = 9	1 × 10 = 10	1 × 11 = 11	1 × 12 = 12
#
# 2 × 1 = 2	2 × 2 = 4	2 × 3 = 6	2 × 4 = 8
# 2 × 5 = 10	2 × 6 = 12	2 × 7 = 14	2 × 8 = 16
# 2 × 9 = 18	2 × 10 = 20	2 × 11 = 22	2 × 12 = 24
#
# 3 × 1 = 3	3 × 2 = 6	3 × 3 = 9	3 × 4 = 12
# 3 × 5 = 15	3 × 6 = 18	3 × 7 = 21	3 × 8 = 24
# 3 × 9 = 27	3 × 10 = 30	3 × 11 = 33	3 × 12 = 36
#
# 4 × 1 = 4	4 × 2 = 8	4 × 3 = 12	4 × 4 = 16
# 4 × 5 = 20	4 × 6 = 24	4 × 7 = 28	4 × 8 = 32
# 4 × 9 = 36	4 × 10 = 40	4 × 11 = 44	4 × 12 = 48
#
# 5 × 1 = 5	5 × 2 = 10	5 × 3 = 15	5 × 4 = 20
# 5 × 5 = 25	5 × 6 = 30	5 × 7 = 35	5 × 8 = 40
# 5 × 9 = 45	5 × 10 = 50	5 × 11 = 55	5 × 12 = 60
#
# 6 × 1 = 6	6 × 2 = 12	6 × 3 = 18	6 × 4 = 24
# 6 × 5 = 30	6 × 6 = 36	6 × 7 = 42	6 × 8 = 48
# 6 × 9 = 54	6 × 10 = 60	6 × 11 = 66	6 × 12 = 72
#
# 7 × 1 = 7	7 × 2 = 14	7 × 3 = 21	7 × 4 = 28
# 7 × 5 = 35	7 × 6 = 42	7 × 7 = 49	7 × 8 = 56
# 7 × 9 = 63	7 × 10 = 70	7 × 11 = 77	7 × 12 = 84
#
# ...

# %% [markdown]
# :::{important} Your Turn 1
# Create another table that only shows square numbers like:
# - 1 × 1 = 1
# - 2 × 2 = 4
# - 3 × 3 = 9
# - ...
# :::

# %%
# Your code here

# %% [markdown]
# ## Bubble Sort Python Code Using For-For Loop

# %%
# Version A
numbers = [6, 5, 3, 1, 8, 7, 2, 4]
last_index = len(numbers) - 1
comparison_count = 0

print("Initial state:", numbers)

for i in range(last_index):
    for j in range(last_index):
        comparison_count += 1
        if numbers[j] > numbers[j + 1]:
            numbers[j], numbers[j + 1] = numbers[j + 1], numbers[j]
    print(f"After pass {i + 1}: ", numbers)

print("Total comparisons in Version A:", comparison_count)
# Out:
# Initial state: [6, 5, 3, 1, 8, 7, 2, 4]
# After pass 1:  [5, 3, 1, 6, 7, 2, 4, 8]
# After pass 2:  [3, 1, 5, 6, 2, 4, 7, 8]
# After pass 3:  [1, 3, 5, 2, 4, 6, 7, 8]
# After pass 4:  [1, 3, 2, 4, 5, 6, 7, 8]
# After pass 5:  [1, 2, 3, 4, 5, 6, 7, 8]
# After pass 6:  [1, 2, 3, 4, 5, 6, 7, 8]
# After pass 7:  [1, 2, 3, 4, 5, 6, 7, 8]
# Total comparisons in Version A: 49

# %%
# Version B
numbers = [6, 5, 3, 1, 8, 7, 2, 4]
last_index = len(numbers) - 1
comparison_count = 0

print("Initial state:", numbers)

for i in range(last_index):
    for j in range(last_index - i):
        comparison_count += 1
        if numbers[j] > numbers[j + 1]:
            numbers[j], numbers[j + 1] = numbers[j + 1], numbers[j]
    print(f"After pass {i + 1}: ", numbers)

print("Total comparisons in Version B:", comparison_count)
# Out:
# Initial state: [6, 5, 3, 1, 8, 7, 2, 4]
# After pass 1:  [5, 3, 1, 6, 7, 2, 4, 8]
# After pass 2:  [3, 1, 5, 6, 2, 4, 7, 8]
# After pass 3:  [1, 3, 5, 2, 4, 6, 7, 8]
# After pass 4:  [1, 3, 2, 4, 5, 6, 7, 8]
# After pass 5:  [1, 2, 3, 4, 5, 6, 7, 8]
# After pass 6:  [1, 2, 3, 4, 5, 6, 7, 8]
# After pass 7:  [1, 2, 3, 4, 5, 6, 7, 8]
# Total comparisons in Version B: 28

# %% [markdown]
# :::{tip} Exercise 1
# Use playing cards to demonstrate the bubble sort.
# :::

# %% [markdown]
# :::{tip} Exercise 2
# Two versions of code, A and B, are shown, Which is the worse version and which is the better version?
# :::

# %% [markdown]
# :::{tip} Exercise 3
# Identify the line of code that makes it better.
# :::

# %%
# Code here

# %% [markdown]
# :::{important} Your Turn 2
# Turn the better version into a function named `bubble_sort`.
# :::

# %%
# Code Your Turn 2

# %% [markdown]
# ## Bubble Sort Pseudocode Using While-For Loop
#
# ```{code}
# :linenos:
# PROCEDURE bubble_sort_version_2(items)
#
#     // Initialise the variables
#     num_items = LEN(items)
#     swapped = True
#
#     // Repeat while one or more swaps have been made
#     WHILE swapped == True
#         swapped = False
#         // Perform a pass
#     	FOR index = 0 TO num_items - 2
#        	    // Compare items to check if they are out of order
#             IF items[index] > items[index + 1] THEN
#             	// Swap the items
#             	temp = items[index]
#             	items[index] = items[index + 1]
#             	items[index + 1] = temp
#                 swapped = True
#             ENDIF
# 	NEXT index
#     ENDWHILE
# ENDPROCEDURE
# ```

# %% [markdown]
# :::{tip} Exercise 4
# Compare the While-For Bubble Sort to For-For Bubble Sort:
#
# - How many loops it has
# - What is the main difference in the While-loop?
# - What data structure do we use here?
# - How do we know the number of items in this structure?
# - In which lines, do we swtich values?
# :::

# %%
def bubble_sort_version_2(items):

    # Initialise the variables
    num_items = len(items)
    swapped = True

    # Repeat while one or more swaps have been made
    while swapped == True:
        swapped = False
        # Perform a pass
        for index in range(0, num_items - 1):
            # Compare items to check if they are out of order
            if items[index] > items[index + 1]:
                # Swap the items
                temp = items[index]
                items[index] = items[index + 1]
                items[index + 1] = temp
                swapped = True


numbers = [6, 5, 3, 1, 8, 7, 2, 4]
bubble_sort_version_2(numbers)
print(numbers)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# :::{tip} Exercise 5
# Between the For-For and While-For versions, which version do you prefer and why?
# :::

# %% [markdown]
# # Linear Search

# %% [markdown]
# :::{iframe} https://www.youtube.com/embed/TwsgCHYmbbA
# :::

# %% [markdown]
# ![linear-search.gif](attachment:3bf04e2b-c4c0-44ec-9cd9-8da5e55d7186.gif)

# %% [markdown]
# ## Pseudocode for Linear Search
#
# Figure 2.26
#
# ```
# ALGORITHM linearSearch()
# { Purpose: Searches through a list of element }
# { Output: Boolean, True if item found, False if not }
# BEGIN
#     Input: searchList, searchItem
#     found <- FALSE
#     FOR eachItem in searchList DO
#         IF eachItem = searchItem THEN
#             found <- TRUE
#             BREAK  { exit loop once found }
#         ENDIF
#     ENDFOR
#     RETURN found
# END
# ```

# %% [markdown]
# :::{tip} Exercise 6
#
# 1. What types of data structures can the linearSearch algorithm be applied to?
# 2. What is the data type for found?
# 3. Does this function `linearSearch()` return a value? If so, what will it be?
# 4. When the `searchItem` is found, how do you stop searching?
# :::

# %% [markdown]
# ## Python for Linear Search

# %%
def linearSearch(searchList, searchItem):
    """
    Searches through a list of elements for a specified item.

    :param searchList: List of elements to search through.
    :param searchItem: Item to search for in the list.
    :return: Boolean, True if item found, False if not.
    """
    found = False
    for eachItem in searchList:
        if eachItem == searchItem:
            found = True
            break  # Exit loop once found
    return found

# Example usage:
searchList = [12, 8, 31, 1, 77, 75, 18]
searchItem = 77
result = linearSearch(searchList, searchItem)
print("Item found:", result)
# Out:
# Item found: True

# %% [markdown]
# :::{tip} Exercise 7
#
# While linear searches are the simplest to implement in almost every programming language, they are also extremely inefficient.
#
# Explain the reason?

# %% [markdown]
# :::{important} Your Turn 3
# Instead of return True or False, return the index (position) of the item in the array.
#
# **Expected output: 4**
# :::

# %%
# Modify the code below
def linearSearch(searchList, searchItem):
    """
    Searches through a list of elements for a specified item.

    :param searchList: List of elements to search through.
    :param searchItem: Item to search for in the list.
    :return: Boolean, True if item found, False if not.
    """
    found = False
    for eachItem in searchList:
        if eachItem == searchItem:
            found = True
            break  # Exit loop once found
    return found

# Example usage:
searchList = [12, 8, 31, 1, 77, 75, 18]
searchItem = 77
result = linearSearch(searchList, searchItem)
print("Item found:", result)
# Out:
# Item found: True
